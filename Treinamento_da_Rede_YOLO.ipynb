# %% [markdown]
# ## 🧠 1. Instalação do Roboflow e Importação do Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="API KEY")
project = rf.workspace("footar").project("football-players-and-ball-5pzj6")
dataset = project.version(1).download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 114.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 124.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Players-and-Ball-1 in yolov5pytorch:: 100%|██████████| 2034/2034 [00:00<00:00, 3207.44it/s]

# %% [markdown]
# ## 📦 2. Clone do Repositório YOLOv5 e Instalação de Dependências

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 17516 (delta 7), reused 0 (delta 0), pack-reused 17496 (from 4)
# Receiving objects: 100% (17516/17516), 16.60 MiB | 14.79 MiB/s, done.
# Resolving deltas: 100% (11995/11995), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 📁 3. Verificação e Ajuste do Caminho do Dataset

# %%
# !ls /content
# Out:
# Football-Players-and-Ball-1  sample_data  yolov5

# %%
# !cat /content/Football-Players-and-Ball-1/data.yaml
# Out:
# names:
# - ball
# - goalkeeper
# - player
# - referee
# nc: 4
# roboflow:
#   license: CC BY 4.0
#   project: football-players-and-ball-5pzj6
#   url: https://universe.roboflow.com/footar/football-players-and-ball-5pzj6/dataset/1
#   version: 1
#   workspace: footar
# test: ../test/images
# train: Football-Players-and-Ball-1/train/images
# val: Football-Players-and-Ball-1/valid/images

# %% [markdown]
# ## ⚙️ 4. Criação e Edição do Arquivo data.yaml

# %%
with open('/content/Football-Players-and-Ball-1/data.yaml', 'w') as f:
    f.write(
        """
names:
- ball
- goalkeeper
- player
- referee
nc: 4

train: /content/Football-Players-and-Ball-1/train/images
val: /content/Football-Players-and-Ball-1/valid/images
test: /content/Football-Players-and-Ball-1/test/images
"""
    )

# %% [markdown]
# ## 🚀 5. Treinamento do Modelo YOLOv5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/Football-Players-and-Ball-1/data.yaml --weights yolov5s.pt --name futebol-yolo --cache
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-26 14:20:48.202031: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753539648.470342    1888 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# ## 🚀 6. Treinamento do Modelo YOLOv5m

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/Football-Players-and-Ball-1/data.yaml --weights yolov5m.pt --name futebol-yolo-medium --cache
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#       47/99       6.9G    0.02828    0.04516   0.003633        363        640:  53% 24/45 [00:09<00:09,  2.31it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       47/99       6.9G    0.02823    0.04525   0.003594        459        640:  56% 25/45 [00:10<00:09,  2.22it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       47/99       6.9G    0.02817    0.04546   0.003619        492        640:  58% 26/45 [00:10<00:08,  2.31it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
